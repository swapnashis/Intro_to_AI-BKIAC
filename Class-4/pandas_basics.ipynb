# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('music.csv')
# df = pd.read_csv('music.csv', sep=',')
df = pd.read_csv('music.csv')

df
# Out:
#     age  gender      genre
# 0    20       1     HipHop
# 1    23       1     HipHop
# 2    25       1     HipHop
# 3    26       1       Jazz
# 4    29       1       Jazz
# 5    30       1       Jazz
# 6    31       1  Classical
# 7    33       1  Classical
# 8    37       1  Classical
# 9    20       0      Dance
# 10   21       0      Dance
# 11   25       0      Dance
# 12   26       0   Acoustic
# 13   27       0   Acoustic
# 14   30       0   Acoustic
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical

# %%
# Extracting the second sheet since Python uses 0-indexing
# df = pd.read_excel('diabetes_multi.xlsx', sheet_name=1)

# %%
df
# Out:
#     age  gender      genre
# 0    20       1     HipHop
# 1    23       1     HipHop
# 2    25       1     HipHop
# 3    26       1       Jazz
# 4    29       1       Jazz
# 5    30       1       Jazz
# 6    31       1  Classical
# 7    33       1  Classical
# 8    37       1  Classical
# 9    20       0      Dance
# 10   21       0      Dance
# 11   25       0      Dance
# 12   26       0   Acoustic
# 13   27       0   Acoustic
# 14   30       0   Acoustic
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical

# %%
# df.to_csv("music_redefined.csv", index=False)

# %%
# df = pd.read_csv("titanic.csv")

# %%
df.head(2)
# Out:
#    age  gender   genre
# 0   20       1  HipHop
# 1   23       1  HipHop

# %%
df.tail()
# Out:
#     age  gender      genre
# 13   27       0   Acoustic
# 14   30       0   Acoustic
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical

# %% [markdown]
# Accessing data elements

# %%
# numpy used indexing a[0]

df['age']
# Out:
# 0     20
# 1     23
# 2     25
# 3     26
# 4     29
# 5     30
# 6     31
# 7     33
# 8     37
# 9     20
# 10    21
# 11    25
# 12    26
# 13    27
# 14    30
# 15    31
# 16    34
# 17    35
# Name: age, dtype: int64

# %%
df['age'].to_numpy()

# %%
df[['age', 'gender']]
# Out:
#     age  gender
# 0    20       1
# 1    23       1
# 2    25       1
# 3    26       1
# 4    29       1
# 5    30       1
# 6    31       1
# 7    33       1
# 8    37       1
# 9    20       0
# 10   21       0
# 11   25       0
# 12   26       0
# 13   27       0
# 14   30       0
# 15   31       0
# 16   34       0
# 17   35       0

# %%
df[df.index == 5]
# Out:
#    age  gender genre
# 5   30       1  Jazz

# %%
df[df.index.isin(range(5,9))]
# Out:
#    age  gender      genre
# 5   30       1       Jazz
# 6   31       1  Classical
# 7   33       1  Classical
# 8   37       1  Classical

# %%
df.loc[5:9]
# Out:
#    age  gender      genre
# 5   30       1       Jazz
# 6   31       1  Classical
# 7   33       1  Classical
# 8   37       1  Classical
# 9   20       0      Dance

# %%
df.loc[df.age<25]
# Out:
#     age  gender   genre
# 0    20       1  HipHop
# 1    23       1  HipHop
# 9    20       0   Dance
# 10   21       0   Dance

# %%
df.iloc[5:9]
# Out:
#    age  gender      genre
# 5   30       1       Jazz
# 6   31       1  Classical
# 7   33       1  Classical
# 8   37       1  Classical

# %%
df.iloc[5:9,:]
# Out:
#    age  gender      genre
# 5   30       1       Jazz
# 6   31       1  Classical
# 7   33       1  Classical
# 8   37       1  Classical

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.rename(columns={"genre":"G"})
# Out:
#     age  gender          G
# 0    20       1     HipHop
# 1    23       1     HipHop
# 2    25       1     HipHop
# 3    26       1       Jazz
# 4    29       1       Jazz
# 5    30       1       Jazz
# 6    31       1  Classical
# 7    33       1  Classical
# 8    37       1  Classical
# 9    20       0      Dance
# 10   21       0      Dance
# 11   25       0      Dance
# 12   26       0   Acoustic
# 13   27       0   Acoustic
# 14   30       0   Acoustic
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical

# %% [markdown]
# Operation on dataframes

# %%
# creating new column

# %%
df['new_age'] = df['age'] + 5
df
# Out:
#     age  gender      genre  new_age
# 0    20       1     HipHop       25
# 1    23       1     HipHop       28
# 2    25       1     HipHop       30
# 3    26       1       Jazz       31
# 4    29       1       Jazz       34
# 5    30       1       Jazz       35
# 6    31       1  Classical       36
# 7    33       1  Classical       38
# 8    37       1  Classical       42
# 9    20       0      Dance       25
# 10   21       0      Dance       26
# 11   25       0      Dance       30
# 12   26       0   Acoustic       31
# 13   27       0   Acoustic       32
# 14   30       0   Acoustic       35
# 15   31       0  Classical       36
# 16   34       0  Classical       39
# 17   35       0  Classical       40

# %%
df['genre'].value_counts()
# Out:
# genre
# Classical    6
# HipHop       3
# Jazz         3
# Dance        3
# Acoustic     3
# Name: count, dtype: int64

# %%
df['genre'].value_counts(normalize=True)
# Out:
# genre
# Classical    0.333333
# HipHop       0.166667
# Jazz         0.166667
# Dance        0.166667
# Acoustic     0.166667
# Name: proportion, dtype: float64

# %%
df.value_counts(subset=['gender', 'genre'], normalize=True)
# Out:
# gender  genre
# 0       Acoustic     0.166667
#         Classical    0.166667
#         Dance        0.166667
# 1       Classical    0.166667
#         HipHop       0.166667
#         Jazz         0.166667
# Name: proportion, dtype: float64

# %% [markdown]
# Aggregating data

# %%
df.groupby("genre").count()[['age']]
# max
# sum
# mode
# Out:
#            age
# genre
# Acoustic     3
# Classical    6
# Dance        3
# HipHop       3
# Jazz         3

# %% [markdown]
# Data visualization

# %%
df.plot(x='age', y='new_age')
# Out:
# <Axes: xlabel='age'>

# %%
# df.plot(x='age', y='genre')

# %%
df['genre'].value_counts(normalize=True).plot.bar()
# Out:
# <Axes: xlabel='genre'>

# %% [markdown]
# Data inspection

# %%
df = pd.read_csv("titanic.csv")

# %%
df.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
df.info(show_counts=True, memory_usage=True, verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.shape
# Out:
# (891, 12)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Dropping

# %%
df_cleaned = df.dropna()
df_cleaned.describe().T
# Out:
#              count        mean         std   min    25%    50%    75%  \
# PassengerId  183.0  455.366120  247.052476  2.00  263.5  457.0  676.0
# Survived     183.0    0.672131    0.470725  0.00    0.0    1.0    1.0
# Pclass       183.0    1.191257    0.515187  1.00    1.0    1.0    1.0
# Age          183.0   35.674426   15.643866  0.92   24.0   36.0   47.5
# SibSp        183.0    0.464481    0.644159  0.00    0.0    0.0    1.0
# Parch        183.0    0.475410    0.754617  0.00    0.0    0.0    1.0
# Fare         183.0   78.682469   76.347843  0.00   29.7   57.0   90.0
#
#                   max
# PassengerId  890.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          3.0000
# Parch          4.0000
# Fare         512.3292

# %% [markdown]
# Imputing missing values

# %%
mean_age = df['Age'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\DELL\disk\brtc\iac\intro_to_ai_bk_29\.conda\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 mean_age = df['Age'].mean()
#
# ...

# %%
df.fillna({'Age':mean_age})
# Out:
#     age  gender      genre  new_age
# 0    20       1     HipHop       25
# 1    23       1     HipHop       28
# 2    25       1     HipHop       30
# 3    26       1       Jazz       31
# 4    29       1       Jazz       34
# 5    30       1       Jazz       35
# 6    31       1  Classical       36
# 7    33       1  Classical       38
# 8    37       1  Classical       42
# 9    20       0      Dance       25
# 10   21       0      Dance       26
# 11   25       0      Dance       30
# 12   26       0   Acoustic       31
# 13   27       0   Acoustic       32
# 14   30       0   Acoustic       35
# 15   31       0  Classical       36
# 16   34       0  Classical       39
# 17   35       0  Classical       40

# %% [markdown]
# Dropping duplicates

# %%
df.drop_duplicates()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
