# %%
import pandas as pd
import numpy as np

titanic_df = pd.read_csv("train.csv")
titanic_df.tail(7)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch           Ticket    Fare Cabin Embarked
# 884    male  25.0      0      0  SOTON/OQ 392076   7.050   NaN        S
# 885  female  39.0      0      5           382652  29.125   NaN        Q
# 886    male  27.0      0      0           211536  13.000   NaN        S
# ...

# %%
titanic_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# X = [['PassengerId','Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']]
# y = [ 'Survived']

# %%
# feature_name = ['Pclass','Age', 'Sex', 'Fare']
feature_name = ['Pclass', 'Age', 'Fare']
label_name =  'Survived'

X = titanic_df[feature_name]
y = titanic_df[label_name]

# %%
X
# Out:
#      Pclass   Age     Fare
# 0         3  22.0   7.2500
# 1         1  38.0  71.2833
# 2         3  26.0   7.9250
# 3         1  35.0  53.1000
# 4         3  35.0   8.0500
# ..      ...   ...      ...
# 886       2  27.0  13.0000
# 887       1  19.0  30.0000
# 888       3   NaN  23.4500
# 889       1  26.0  30.0000
# 890       3  32.0   7.7500
#
# [891 rows x 3 columns]

# %%
# X['Sex'].unique()

# %%
# titanic_df['Sex'] = titanic_df['Sex'].replace(
#     {
#         'male' : 0,
#         'female' : 1
#     }
# )

# %%
# titanic_df['Embarked'].unique()

# %%
# pd.get_dummies(titanic_df, columns=['Embarked'])

# %%
X.head(2)
# Out:
#    Pclass   Age     Fare
# 0       3  22.0   7.2500
# 1       1  38.0  71.2833

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(X_train, y_train)

from sklearn.metrics import accuracy_score

y_hat = model.predict(X_test)

accuracy_score(y_test, y_hat)
# Out:
# 0.6927374301675978

# %%
tit_test_df = pd.read_csv('test.csv')

# tit_test_df['Sex'] = tit_test_df['Sex'].replace({
#     'male' : 0,
#     'female' : 1
# })

tit_test_df.head(2)
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
#
#    Parch  Ticket    Fare Cabin Embarked
# 0      0  330911  7.8292   NaN        Q
# 1      0  363272  7.0000   NaN        S

# %%
X_t = tit_test_df[feature_name]
y_hat = model.predict(X_t)

tit_test_df['Survived'] = y_hat
tit_test_df.head(3)
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2          894       2         Myles, Mr. Thomas Francis    male  62.0      0
#
#    Parch  Ticket    Fare Cabin Embarked  Survived
# 0      0  330911  7.8292   NaN        Q         0
# 1      0  363272  7.0000   NaN        S         0
# 2      0  240276  9.6875   NaN        Q         1

# %%
tit_test_df[['PassengerId', 'Survived']]
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         1
# 3            895         1
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         1
#
# [418 rows x 2 columns]

# %%
tit_test_df[['PassengerId', 'Survived']].to_csv(
    'titanic-submission.csv', index=False
)

# %% [markdown]
# # Regression

# %%
ad_df = pd.read_csv('advertising.csv', index_col=0)

ad_df.head(4)
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5

# %%
ad_df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
import matplotlib.pyplot as plt

plt.scatter(ad_df['TV'], ad_df['Sales'])
plt.xlabel('TV')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
import matplotlib.pyplot as plt

plt.scatter(ad_df['Radio'], ad_df['Sales'])
plt.xlabel('Radio')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
import matplotlib.pyplot as plt

plt.scatter(ad_df['Newspaper'], ad_df['Sales'])
plt.xlabel('Newspaper')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

sns.pairplot(ad_df)

# %%
sns.heatmap(ad_df.corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(ad_df.corr(), cmap='YlGnBu', annot=True)
# Out:
# <Axes: >

# %%
feature_name = ['TV']
label_name = 'Sales'

X = ad_df[feature_name]
y = ad_df[label_name]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

model =  LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import root_mean_squared_error

y_hat = model.predict(X_test)

root_mean_squared_error(y_test, y_hat)
# Out:
# 3.342557070339613

# %%
plt.scatter(X_test['TV'], y_test)

plt.xlabel('TV')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
plt.scatter(X_test['TV'], y_test)
plt.scatter(X_test['TV'], y_hat, color = 'green')
plt.xlabel('TV')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
result_df = pd.DataFrame()
result_df['Tv'] = X_test['TV']
result_df['y_hat'] = y_hat
result_df['y_ground'] = y_test
result_df['deviation_percent'] = 100 * abs(y_hat - y_test) / y_test
result_df.head()
# Out:
#         Tv      y_hat  y_ground  deviation_percent
# 114  209.6  17.320698      15.9           8.935209
# 132  265.2  20.072717      12.7          58.052886
# 160  131.7  13.464903      12.9           4.379092
# 9      8.6   7.371855       4.8          53.580318
# 70   216.8  17.677075      22.3          20.730606

# %%
plt.hist(result_df['deviation_percent'])
# Out:
# (array([10.,  9.,  6.,  6.,  2.,  0.,  1.,  2.,  3.,  1.]),
#  array([ 0.15383472,  6.77084631, 13.3878579 , 20.00486948, 26.62188107,
#         33.23889266, 39.85590425, 46.47291584, 53.08992743, 59.70693902,
#         66.3239506 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(result_df['deviation_percent'], bins=10)
# Out:
# (array([10.,  9.,  6.,  6.,  2.,  0.,  1.,  2.,  3.,  1.]),
#  array([ 0.15383472,  6.77084631, 13.3878579 , 20.00486948, 26.62188107,
#         33.23889266, 39.85590425, 46.47291584, 53.08992743, 59.70693902,
#         66.3239506 ]),
#  <BarContainer object of 10 artists>)
