# %%
# %pip install numpy pandas matplotlib scikit-learn XGBoost seaborn
# Out:
# Requirement already satisfied: numpy in d:\intro_to_ai-bkiac-main\.conda\lib\site-packages (2.0.0)
# Requirement already satisfied: pandas in d:\intro_to_ai-bkiac-main\.conda\lib\site-packages (2.2.2)
# Requirement already satisfied: matplotlib in d:\intro_to_ai-bkiac-main\.conda\lib\site-packages (3.9.0)
# Requirement already satisfied: scikit-learn in d:\intro_to_ai-bkiac-main\.conda\lib\site-packages (1.5.0)
# Requirement already satisfied: XGBoost in d:\intro_to_ai-bkiac-main\.conda\lib\site-packages (2.1.0)
# Requirement already satisfied: seaborn in d:\intro_to_ai-bkiac-main\.conda\lib\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\intro_to_ai-bkiac-main\.conda\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\intro_to_ai-bkiac-main\.conda\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in d:\intro_to_ai-bkiac-main\.conda\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in d:\intro_to_ai-bkiac-main\.conda\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\intro_to_ai-bkiac-main\.conda\lib\site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\intro_to_ai-bkiac-main\.conda\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python312\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in d:\intro_to_ai-bkiac-main\.conda\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\intro_to_ai-bkiac-main\.conda\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: scipy>=1.6.0 in d:\intro_to_ai-bkiac-main\.conda\lib\site-packages (from scikit-learn) (1.14.0)
# Requirement already satisfied: joblib>=1.2.0 in d:\intro_to_ai-bkiac-main\.conda\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\intro_to_ai-bkiac-main\.conda\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip upgrade numpy pandas matplotlib scikit-learn XGBoost seaborn
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "upgrade"

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt

# %%
notes_df = pd.read_csv('banknote-counterfeiting.csv')

notes_df.head(5)
# Out:
#      VWTI     SWTI     CWTI        EI  Class
# 0  2.2634  -4.4862   3.6558 -0.612510      0
# 1  3.2718   1.7837   2.1161  0.613340      0
# 2 -3.9411 -12.8792  13.0597 -3.312500      1
# 3  0.5195  -3.2633   3.0895 -0.984900      0
# 4  2.5698  -4.4076   5.9856  0.078002      0

# %%
notes_df.columns
# Out:
# Index(['VWTI', 'SWTI', 'CWTI', 'EI', 'Class'], dtype='object')

# %%
feature_names = ['VWTI', 'SWTI', 'CWTI', 'EI']
label_name = ['Class']

X = notes_df[feature_names]
y = notes_df[label_name]

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=303)

# %%
from sklearn.tree import DecisionTreeClassifier

decisionTreeModel = DecisionTreeClassifier()
decisionTreeModel.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_hat = decisionTreeModel.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_hat)
# Out:
# 0.9772727272727273

# %%
from sklearn.ensemble import RandomForestClassifier

randomForestModel = RandomForestClassifier()
randomForestModel.fit(X_train, y_train)
# Out:
# d:\Intro_to_AI-BKIAC-main\.conda\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier()

# %%
y_hat_rf = randomForestModel.predict(X_test)

# %%
accuracy_score(y_test, y_hat_rf)
# Out:
# 0.9954545454545455

# %%
from xgboost import XGBClassifier

xgbModel = XGBClassifier()
xgbModel.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_hat_xgb = xgbModel.predict(X_test)
accuracy_score(y_test, y_hat_xgb)
# Out:
# 0.9954545454545455

# %%
from sklearn.linear_model import LinearRegression

linearRegressionModel = LinearRegression()
linearRegressionModel.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_hat_lr = linearRegressionModel.predict(X_test)

# %%
accuracy_score(y_test, y_hat_lr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 accuracy_score(y_test, y_hat_lr)
#
# File d:\Intro_to_AI-BKIAC-main\.conda\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File d:\Intro_to_AI-BKIAC-main\.conda\Lib\site-packages\sklearn\metrics\_classification.py:222, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     161 """Accuracy classification score.
#     162
#     163 In multilabel classification, this function computes subset accuracy:
#    (...)
#     218 0.5
#     219 """
#     221 # Compute accuracy for each possible representation
# --> 222 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     223 check_consistent_length(y_true, y_pred, sample_weight)
#     224 if y_type.startswith("multilabel"):
#
# File d:\Intro_to_AI-BKIAC-main\.conda\Lib\site-packages\sklearn\metrics\_classification.py:108, in _check_targets(y_true, y_pred)
#     105     y_type = {"multiclass"}
#     107 if len(y_type) > 1:
# --> 108     raise ValueError(
#     109         "Classification metrics can't handle a mix of {0} and {1} targets".format(
#     110             type_true, type_pred
#     111         )
#     112     )
#     114 # We can't have more than one value on y_type => The set is no more needed
#     115 y_type = y_type.pop()
#
# ValueError: Classification metrics can't handle a mix of binary and continuous targets
